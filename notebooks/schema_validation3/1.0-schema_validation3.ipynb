# %% [markdown]
# # Data Snapshot Metadata Schema Validation 3
#
# # Calibration0: Complete Schema
#
# This run supplies the complete generated Schema v1.2, parent-document context, and the twelve existing calibration snapshots. Successful results are resumable by snapshot filename, and errors are logged separately. Review the paths and arguments below before running the final cell.

# %%
from data_snapshot.constants import ROOT
from data_snapshot.schema_validation3 import run_validation

# %%
METADATA_DIR = ROOT / "notebooks/schema_validation1/data/metadata"
CONFIG_PATH = ROOT / "src/data_snapshot/schema_validation3/config/default.json"
SLEEP_SECONDS = 0.2

# Calibration0: twelve snapshots with the complete generated Schema v1.2.
SNAPSHOTS_DIR = ROOT / "notebooks/schema_validation1/data/calibration0"
RESULTS_PATH = ROOT / "notebooks/schema_validation3/outputs/calibration_results0.jsonl"
ERRORS_PATH = ROOT / "notebooks/schema_validation3/outputs/calibration_errors0.jsonl"
SNAPSHOT_FILE_NAMES = None
EXCLUDED_SCHEMA_FIELDS = ()

# %%
run_arguments = {
    "snapshots_dir": SNAPSHOTS_DIR,
    "metadata_dir": METADATA_DIR,
    "results_path": RESULTS_PATH,
    "errors_path": ERRORS_PATH,
    "config_path": CONFIG_PATH,
    "snapshot_file_names": SNAPSHOT_FILE_NAMES,
    "excluded_schema_fields": EXCLUDED_SCHEMA_FIELDS,
    "sleep_seconds": SLEEP_SECONDS,
}
run_arguments
# Out:
# {'snapshots_dir': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation1/data/calibration0'),
#  'metadata_dir': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation1/data/metadata'),
#  'results_path': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation3/outputs/calibration_results0.jsonl'),
#  'errors_path': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation3/outputs/calibration_errors0.jsonl'),
#  'config_path': PosixPath('/home/ajd/data-snapshot-annotation/src/data_snapshot/schema_validation3/config/default.json'),
#  'snapshot_file_names': None,
#  'excluded_schema_fields': (),
#  'sleep_seconds': 0.2}

# %%
summary = run_validation(**run_arguments)
summary
# Out:
# Validating snapshots:   0%|          | 0/12 [00:00<?, ?snapshot/s]
# RunSummary(discovered=12, skipped=7, succeeded=5, failed=0)
