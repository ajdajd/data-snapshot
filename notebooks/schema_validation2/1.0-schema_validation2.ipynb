# %% [markdown]
# # Data Snapshot Metadata Schema Validation 2
#
# Calibration3 is a counterfactual sensitivity test, not a substantive schema-coverage run. It supplies one snapshot with an explicit data-source statement and footer note, together with a model-facing schema from which only `data_source` and `interpretive_note` have been removed. A data-source-like critical or possible gap is the required sensitivity signal; an interpretive-note-like gap is secondary because the displayed note only points to discussion elsewhere. Keep Calibration3 outputs separate from the substantive Validation2 results. Do not run any stage without explicit API authorization.

# %%
from data_snapshot.constants import ROOT
from data_snapshot.schema_validation2 import run_validation

# %%
METADATA_DIR = ROOT / "notebooks/schema_validation1/data/metadata"
SCHEMA_PATH = (
    ROOT
    / "src/data_snapshot/schema_validation2/schema_v1.1.1_data_source_interpretive_note_ablated.md"
)
CONFIG_PATH = ROOT / "src/data_snapshot/schema_validation2/config/default.json"
SLEEP_SECONDS = 0.2

# Calibration3 counterfactual: one explicit footer, with two fields ablated.
SNAPSHOTS_DIR = ROOT / "notebooks/schema_validation2/data/calibration3"
RESULTS_PATH = ROOT / "notebooks/schema_validation2/outputs/calibration_results3.jsonl"
ERRORS_PATH = ROOT / "notebooks/schema_validation2/outputs/calibration_errors3.jsonl"

# %%
run_arguments = {
    "snapshots_dir": SNAPSHOTS_DIR,
    "metadata_dir": METADATA_DIR,
    "schema_path": SCHEMA_PATH,
    "results_path": RESULTS_PATH,
    "errors_path": ERRORS_PATH,
    "config_path": CONFIG_PATH,
    "sleep_seconds": SLEEP_SECONDS,
}
run_arguments
# Out:
# {'snapshots_dir': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation2/data/calibration3'),
#  'metadata_dir': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation1/data/metadata'),
#  'schema_path': PosixPath('/home/ajd/data-snapshot-annotation/src/data_snapshot/schema_validation2/schema_v1.1.1_data_source_interpretive_note_ablated.md'),
#  'results_path': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation2/outputs/calibration_results3.jsonl'),
#  'errors_path': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation2/outputs/calibration_errors3.jsonl'),
#  'config_path': PosixPath('/home/ajd/data-snapshot-annotation/src/data_snapshot/schema_validation2/config/default.json'),
#  'sleep_seconds': 0.2}

# %%
summary = run_validation(**run_arguments)
summary
# Out:
# Validating snapshots:   0%|          | 0/1 [00:00<?, ?snapshot/s]
# RunSummary(discovered=1, skipped=0, succeeded=1, failed=0)
