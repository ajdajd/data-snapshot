# %% [markdown]
# # Data Snapshot Metadata Schema Validation 2
#
# # Full Schema Coverage Run
#
# The calibration sequence is complete. This run supplies the complete 36-field model-facing Schema v1.1.1 and all 202 held-out snapshots. Successful results are resumable by snapshot filename, and errors are logged separately for review or rerunning. Calibration outputs and ablated schemas remain separate methodological controls. Review the paths below before running the final cell.

# %%
from data_snapshot.constants import ROOT
from data_snapshot.schema_validation2 import run_validation

# %%
METADATA_DIR = ROOT / "notebooks/schema_validation1/data/metadata"
SCHEMA_PATH = (
    ROOT / "src/data_snapshot/schema_validation2/schema_v1.1.1_model_facing.md"
)
CONFIG_PATH = ROOT / "src/data_snapshot/schema_validation2/config/default.json"
SLEEP_SECONDS = 0.2

# Full run: all 202 held-out snapshots with the complete model-facing schema.
SNAPSHOTS_DIR = ROOT / "notebooks/schema_validation1/data/snapshots"
RESULTS_PATH = ROOT / "notebooks/schema_validation2/outputs/results.jsonl"
ERRORS_PATH = ROOT / "notebooks/schema_validation2/outputs/errors.jsonl"

# %%
run_arguments = {
    "snapshots_dir": SNAPSHOTS_DIR,
    "metadata_dir": METADATA_DIR,
    "schema_path": SCHEMA_PATH,
    "results_path": RESULTS_PATH,
    "errors_path": ERRORS_PATH,
    "config_path": CONFIG_PATH,
    "sleep_seconds": SLEEP_SECONDS,
}
run_arguments
# Out:
# {'snapshots_dir': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation1/data/snapshots'),
#  'metadata_dir': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation1/data/metadata'),
#  'schema_path': PosixPath('/home/ajd/data-snapshot-annotation/src/data_snapshot/schema_validation2/schema_v1.1.1_model_facing.md'),
#  'results_path': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation2/outputs/results.jsonl'),
#  'errors_path': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation2/outputs/errors.jsonl'),
#  'config_path': PosixPath('/home/ajd/data-snapshot-annotation/src/data_snapshot/schema_validation2/config/default.json'),
#  'sleep_seconds': 0.2}

# %%
summary = run_validation(**run_arguments)
summary
# Out:
# Validating snapshots:   0%|          | 0/202 [00:00<?, ?snapshot/s]
# RunSummary(discovered=202, skipped=0, succeeded=202, failed=0)
