# %% [markdown]
# # Data Snapshot Metadata Schema Validation 2
#
# Run calibration0 first. If changes are needed, use a separately selected calibration1 set before the full run. After the prompt and output model are frozen, change the three run-specific paths to process the complete 202-snapshot sample into fresh output files. Do not run any stage without explicit API authorization.

# %%
from data_snapshot.constants import ROOT
from data_snapshot.schema_validation2 import run_validation

# %%
METADATA_DIR = ROOT / "notebooks/schema_validation1/data/metadata"
SCHEMA_PATH = (
    ROOT
    / "src/data_snapshot/metadata_extraction/schema/Data Snapshot Metadata Schema v1.1.1.md"
)
CONFIG_PATH = ROOT / "src/data_snapshot/schema_validation2/config/default.json"
SLEEP_SECONDS = 0.2

# Calibration0 run
SNAPSHOTS_DIR = ROOT / "notebooks/schema_validation1/data/calibration0"
RESULTS_PATH = ROOT / "notebooks/schema_validation2/outputs/calibration_results0.jsonl"
ERRORS_PATH = ROOT / "notebooks/schema_validation2/outputs/calibration_errors0.jsonl"

# Full run:
# SNAPSHOTS_DIR = ROOT / "notebooks/schema_validation1/data/snapshots"
# RESULTS_PATH = ROOT / "notebooks/schema_validation2/outputs/results.jsonl"
# ERRORS_PATH = ROOT / "notebooks/schema_validation2/outputs/errors.jsonl"

# %%
run_arguments = {
    "snapshots_dir": SNAPSHOTS_DIR,
    "metadata_dir": METADATA_DIR,
    "schema_path": SCHEMA_PATH,
    "results_path": RESULTS_PATH,
    "errors_path": ERRORS_PATH,
    "config_path": CONFIG_PATH,
    "sleep_seconds": SLEEP_SECONDS,
}
run_arguments
# Out:
# {'snapshots_dir': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation1/data/calibration0'),
#  'metadata_dir': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation1/data/metadata'),
#  'schema_path': PosixPath('/home/ajd/data-snapshot-annotation/src/data_snapshot/metadata_extraction/schema/Data Snapshot Metadata Schema v1.1.1.md'),
#  'results_path': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation2/outputs/calibration_results0.jsonl'),
#  'errors_path': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation2/outputs/calibration_errors0.jsonl'),
#  'config_path': PosixPath('/home/ajd/data-snapshot-annotation/src/data_snapshot/schema_validation2/config/default.json'),
#  'sleep_seconds': 0.2}

# %%
summary = run_validation(**run_arguments)
summary
# Out:
# Validating snapshots:   0%|          | 0/12 [00:00<?, ?snapshot/s]
# RunSummary(discovered=12, skipped=0, succeeded=12, failed=0)
