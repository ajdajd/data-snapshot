# %%
from dsa.constants import ROOT
from dsa.utils import load_json
import pandas as pd

# %%
res_dir = ROOT / "data/paper/"
res_files = sorted(list(res_dir.glob("report_*.json")))

res_files
# Out:
# [PosixPath('/home/ajd/data-snapshot-annotation/data/paper/report_doclayoutyolo_paper_combined.json'),
#  PosixPath('/home/ajd/data-snapshot-annotation/data/paper/report_tfid-large_paper_combined.json'),
#  PosixPath('/home/ajd/data-snapshot-annotation/data/paper/report_yolo11_paper_combined.json'),
#  PosixPath('/home/ajd/data-snapshot-annotation/data/paper/report_yolo26_paper_combined.json')]

# %%
for f in res_files:
    f.resolve(strict=True)

# %%
thresholds = [
    "0.5",
    # "0.75",
]
classes = [
    "Figure",
    "Table",
]
metrics = {
    "precision": "detection",
    "recall": "detection",
    "mean_iou": "spatial accuracy",
    "mean_area_precision": "spatial accuracy",
    "mean_area_recall": "spatial accuracy",
}

# %%
cols = []
for r in res_files:
    row = {}
    row["filename"] = r.name

    res = load_json(r)
    for t in thresholds:
        for c in classes:
            for m in metrics:
                row[f"[{c}] {m} @ {t}"] = res["metrics"][t]["per_class"][c][m]

    cols.append(row)

# %%
df = pd.DataFrame(cols).set_index("filename").transpose()
df
# Out:
# filename                            report_doclayoutyolo_paper_combined.json  \
# [Figure] precision @ 0.5                                            0.541980
# [Figure] recall @ 0.5                                               0.800577
# [Figure] mean_iou @ 0.5                                             0.822184
# [Figure] mean_area_precision @ 0.5                                  0.995778
# [Figure] mean_area_recall @ 0.5                                     0.826086
# [Table] precision @ 0.5                                             0.416915
# [Table] recall @ 0.5                                                0.883035
# [Table] mean_iou @ 0.5                                              0.845423
# [Table] mean_area_precision @ 0.5                                   0.990594
# [Table] mean_area_recall @ 0.5                                      0.854232
#
# filename                            report_tfid-large_paper_combined.json  \
# [Figure] precision @ 0.5                                         0.613711
# [Figure] recall @ 0.5                                            0.464771
# [Figure] mean_iou @ 0.5                                          0.874181
# [Figure] mean_area_precision @ 0.5                               0.928676
# [Figure] mean_area_recall @ 0.5                                  0.941454
# [Table] precision @ 0.5                                          0.501585
# [Table] recall @ 0.5                                             0.833509
# [Table] mean_iou @ 0.5                                           0.912593
# [Table] mean_area_precision @ 0.5                                0.969842
# [Table] mean_area_recall @ 0.5                                   0.941631
#
# filename                            report_yolo11_paper_combined.json  \
# [Figure] precision @ 0.5                                     0.372549
# [Figure] recall @ 0.5                                        0.759374
# [Figure] mean_iou @ 0.5                                      0.818971
# [Figure] mean_area_precision @ 0.5                           0.989187
# [Figure] mean_area_recall @ 0.5                              0.828534
# [Table] precision @ 0.5                                      0.433748
# [Table] recall @ 0.5                                         0.845100
# [Table] mean_iou @ 0.5                                       0.824396
# [Table] mean_area_precision @ 0.5                            0.994154
# [Table] mean_area_recall @ 0.5                               0.829245
#
# filename                            report_yolo26_paper_combined.json
# [Figure] precision @ 0.5                                     0.380858
# [Figure] recall @ 0.5                                        0.713226
# [Figure] mean_iou @ 0.5                                      0.820080
# [Figure] mean_area_precision @ 0.5                           0.988926
# [Figure] mean_area_recall @ 0.5                              0.830033
# [Table] precision @ 0.5                                      0.403014
# [Table] recall @ 0.5                                         0.873551
# [Table] mean_iou @ 0.5                                       0.835151
# [Table] mean_area_precision @ 0.5                            0.993108
# [Table] mean_area_recall @ 0.5                               0.841255

# %%
df.to_clipboard()
