# %% [markdown]
# # Data Snapshot Metadata Schema Validation 3
#
# # Full Run: Complete Schema
#
# This run supplies the complete generated Schema v1.2, parent-document context, and the 202 snapshots assessed in Validation 2. Successful results are resumable by snapshot filename, and errors are logged separately. Review the paths and arguments below before running the final cell.

# %%
from data_snapshot.constants import ROOT
from data_snapshot.schema_validation3 import run_validation

# %%
METADATA_DIR = ROOT / "notebooks/schema_validation1/data/metadata"
CONFIG_PATH = ROOT / "src/data_snapshot/schema_validation3/config/default.json"
SLEEP_SECONDS = 0.2

# Full run: all 202 Validation 2 snapshots with the complete Schema v1.2.
SNAPSHOTS_DIR = ROOT / "notebooks/schema_validation1/data/snapshots"
RESULTS_PATH = ROOT / "notebooks/schema_validation3/outputs/results.jsonl"
ERRORS_PATH = ROOT / "notebooks/schema_validation3/outputs/errors.jsonl"
SNAPSHOT_FILE_NAMES = None
EXCLUDED_SCHEMA_FIELDS = ()

# %%
run_arguments = {
    "snapshots_dir": SNAPSHOTS_DIR,
    "metadata_dir": METADATA_DIR,
    "results_path": RESULTS_PATH,
    "errors_path": ERRORS_PATH,
    "config_path": CONFIG_PATH,
    "snapshot_file_names": SNAPSHOT_FILE_NAMES,
    "excluded_schema_fields": EXCLUDED_SCHEMA_FIELDS,
    "sleep_seconds": SLEEP_SECONDS,
}
run_arguments
# Out:
# {'snapshots_dir': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation1/data/snapshots'),
#  'metadata_dir': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation1/data/metadata'),
#  'results_path': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation3/outputs/results.jsonl'),
#  'errors_path': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation3/outputs/errors.jsonl'),
#  'config_path': PosixPath('/home/ajd/data-snapshot-annotation/src/data_snapshot/schema_validation3/config/default.json'),
#  'snapshot_file_names': None,
#  'excluded_schema_fields': (),
#  'sleep_seconds': 0.2}

# %%
summary = run_validation(**run_arguments)
summary
# Out:
# Validating snapshots:   0%|          | 0/202 [00:00<?, ?snapshot/s]
# RunSummary(discovered=202, skipped=0, succeeded=202, failed=0)
