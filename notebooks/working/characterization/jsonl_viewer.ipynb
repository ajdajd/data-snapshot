# %%
import pandas as pd

df = pd.read_json("data/results_prwp_batch1.jsonl", lines=True)
# df = pd.read_json("data/results_refugee_batch1.jsonl", lines=True)
df
# Out:
#                           snapshot_id  \
# 0     document_10069312_table_006.png
# 1    document_11958451_figure_002.png
# 2    document_11958451_figure_021.png
# 3       document_700615_table_004.png
# 4     document_11958451_table_001.png
# ..                                ...
# 392  document_11867889_figure_012.png
# 393    document_6731296_table_002.png
# 394   document_10002285_table_000.png
# 395    document_700561_figure_004.png
# 396   document_1689472_figure_001.png
#
#                                             image_path source_label  \
# 0     data/prwp_batch1/document_10069312_table_006.png         PRWP
# 1    data/prwp_batch1/document_11958451_figure_002.png         PRWP
# 2    data/prwp_batch1/document_11958451_figure_021.png         PRWP
# 3       data/prwp_batch1/document_700615_table_004.png         PRWP
# 4     data/prwp_batch1/document_11958451_table_001.png         PRWP
# ..                                                 ...          ...
# 392  data/prwp_batch1/document_11867889_figure_012.png         PRWP
# 393    data/prwp_batch1/document_6731296_table_002.png         PRWP
# 394   data/prwp_batch1/document_10002285_table_000.png         PRWP
# 395    data/prwp_batch1/document_700561_figure_004.png         PRWP
# 396   data/prwp_batch1/document_1689472_figure_001.png         PRWP
#
#                                             llm_output  \
# 0    {'visible_text_label': 'Table 7: Intra Africa ...
# 1    {'visible_text_label': 'Figure 2: Russia: Infl...
# 2    {'visible_text_label': 'Figure 20. Average oil...
# 3    {'visible_text_label': 'Table A-2 - Dependent ...
# 4    {'visible_text_label': 'Table 2. Consolidated ...
# ..                                                 ...
# 392  {'visible_text_label': 'Figure 14. Evolution o...
# 393  {'visible_text_label': 'Table 3
# Compensation f...
# 394  {'visible_text_label': 'Table 1 Summary statis...
# 395  {'visible_text_label': 'FREQUENCY DISTRIBUTION...
# 396  {'visible_text_label': 'Figure 2: Frequency Di...
#
#                                             raw_output  \
# 0    {\n  "visible_text_label": "Table 7: Intra Afr...
# 1    {\n  "visible_text_label": "Figure 2: Russia: ...
# 2    {\n  "visible_text_label": "Figure 20. Average...
# 3    {\n  "visible_text_label": "Table A-2 - Depend...
# 4    ```json\n{\n  "visible_text_label": "Table 2. ...
# ..                                                 ...
# 392  {\n  "visible_text_label": "Figure 14. Evoluti...
# 393  ```json\n{\n  "visible_text_label": "Table 3\n...
# 394  ```json\n{\n  "visible_text_label": "Table 1 S...
# 395  {\n  "visible_text_label": "FREQUENCY DISTRIBU...
# 396  {\n  "visible_text_label": "Figure 2: Frequenc...
#
#                                                  usage  \
# 0    {'input_tokens': 26214, 'input_tokens_details'...
# 1    {'input_tokens': 49095, 'input_tokens_details'...
# 2    {'input_tokens': 26427, 'input_tokens_details'...
# 3    {'input_tokens': 26186, 'input_tokens_details'...
# 4    {'input_tokens': 49095, 'input_tokens_details'...
# ..                                                 ...
# 392  {'input_tokens': 48961, 'input_tokens_details'...
# 393  {'input_tokens': 26387, 'input_tokens_details'...
# 394  {'input_tokens': 48892, 'input_tokens_details'...
# 395  {'input_tokens': 26383, 'input_tokens_details'...
# 396  {'input_tokens': 37955, 'input_tokens_details'...
#
#                                                   cost error
# 0    {'input_tokens': 26214, 'output_tokens': 157, ...  None
# 1    {'input_tokens': 49095, 'output_tokens': 157, ...  None
# 2    {'input_tokens': 26427, 'output_tokens': 130, ...  None
# 3    {'input_tokens': 26186, 'output_tokens': 127, ...  None
# 4    {'input_tokens': 49095, 'output_tokens': 145, ...  None
# ..                                                 ...   ...
# 392  {'input_tokens': 48961, 'output_tokens': 146, ...  None
# 393  {'input_tokens': 26387, 'output_tokens': 141, ...  None
# 394  {'input_tokens': 48892, 'output_tokens': 138, ...  None
# 395  {'input_tokens': 26383, 'output_tokens': 132, ...  None
# 396  {'input_tokens': 37955, 'output_tokens': 120, ...  None
#
# [397 rows x 8 columns]

# %%
pd.json_normalize(df["cost"])["total_cost_usd"].sum()
# Out:
# np.float64(2.151855)

# %%
pd.json_normalize(df["cost"])["total_cost_usd"].mean()
# Out:
# np.float64(0.00542028967254408)

# %%
pd.json_normalize(df["cost"])["total_cost_usd"].std()
# Out:
# np.float64(0.001305339974376869)

# %%
0.006 * 2480 / 5
# Out:
# 2.976
