# %%
import glob
import pandas as pd

# %% [markdown]
# # Load files

# %%
files = glob.glob("data/results_*.jsonl")
files
# Out:
# ['data/results_refugee.jsonl']

# %%
df = pd.concat([pd.read_json(x, lines=True) for x in files]).reset_index(drop=True)
df
# Out:
#                                          snapshot_id   source         model  \
# 0  121_PAD1190-PAD-P152848-PUBLIC-Box391435B-LB-E...  refugee       gpt-5.5
# 1                       197_multi-page_table_004.png  refugee       gpt-5.5
# 2  121_PAD1190-PAD-P152848-PUBLIC-Box391435B-LB-E...  refugee  gpt-5.4-mini
# 3                       197_multi-page_table_004.png  refugee  gpt-5.4-mini
#
#                                           raw_output  \
# 0  {"fields":[{"metadata_field":"figure_title","o...
# 1  {"fields":[{"metadata_field":"table_title","ob...
# 2  {"fields":[{"metadata_field":"figure_title","o...
# 3  {"fields":[{"metadata_field":"table_title","ob...
#
#                                                usage  \
# 0  {'input_tokens': 12569, 'input_tokens_details'...
# 1  {'input_tokens': 13570, 'input_tokens_details'...
# 2  {'input_tokens': 12569, 'input_tokens_details'...
# 3  {'input_tokens': 13570, 'input_tokens_details'...
#
#                                                 cost     status  \
# 0  {'input_tokens': 12569, 'output_tokens': 1862,...  completed
# 1  {'input_tokens': 13570, 'output_tokens': 1416,...  completed
# 2  {'input_tokens': 12569, 'output_tokens': 2758,...  completed
# 3  {'input_tokens': 13570, 'output_tokens': 3004,...  completed
#
#    incomplete_details                                      parsed_output  \
# 0                 NaN  {'fields': [{'metadata_field': 'figure_title',...
# 1                 NaN  {'fields': [{'metadata_field': 'table_title', ...
# 2                 NaN  {'fields': [{'metadata_field': 'figure_title',...
# 3                 NaN  {'fields': [{'metadata_field': 'table_title', ...
#
#    error
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN

# %%
# df = df[df["model"] == "gpt-5.4-mini"].copy()

# %% [markdown]
# # Cost

# %%
df = df.reset_index(drop=True).join(pd.json_normalize(df["cost"]))

total = df["total_cost_usd"].sum()
mean = df["total_cost_usd"].mean()
std = df["total_cost_usd"].std()

print(f"Total cost: ${total:.2f}")
print(f"Ave cost per snapshot: ${mean:.4f}")
print(f"Std dev: ${std:.4f}")
# Out:
# Total cost: $0.27
# Ave cost per snapshot: $0.0686
# Std dev: $0.0531

# %%
df.groupby(["source", "model"]).agg(
    count=("source", "count"),
    total_cost_usd=("total_cost_usd", "sum"),
    ave_cost_usd=("total_cost_usd", "mean"),
    std_cost_usd=("total_cost_usd", "std"),
)
# Out:
#                       count  total_cost_usd  ave_cost_usd  std_cost_usd
# source  model
# refugee gpt-5.4-mini      2        0.045534      0.022767      0.001314
#         gpt-5.5           2        0.229035      0.114517      0.005922

# %% [markdown]
# # Output tokens

# %%
total = df["output_tokens"].sum()
mean = df["output_tokens"].mean()
std = df["output_tokens"].std()

print(f"Total output tokens: {total}")
print(f"Ave output token per snapshot: {mean}")
print(f"Std dev: {std:.2f}")
# Out:
# Total output tokens: 9040
# Ave output token per snapshot: 2260.0
# Std dev: 746.61

# %%
df.groupby(["source", "model"]).agg(
    count=("source", "count"),
    total_output_tokens=("output_tokens", "sum"),
    ave_output_tokens=("output_tokens", "mean"),
    std_output_tokens=("output_tokens", "std"),
)
# Out:
#                       count  total_output_tokens  ave_output_tokens  \
# source  model
# refugee gpt-5.4-mini      2                 5762             2881.0
#         gpt-5.5           2                 3278             1639.0
#
#                       std_output_tokens
# source  model
# refugee gpt-5.4-mini         173.948268
#         gpt-5.5              315.369624

# %% [markdown]
# # Raw output

# %%
# df

# %%
# df.loc[0, "raw_output"]

# %% [markdown]
# # Parsed output

# %%
# df.loc[0, "parsed_output"]["fields"]
