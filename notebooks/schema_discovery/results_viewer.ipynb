# %%
import glob
import pandas as pd

# %% [markdown]
# # Load files

# %%
files = glob.glob("data/results_*.jsonl")
files
# Out:
# ['data/results_refugee.jsonl',
#  'data/results_unhcr.jsonl',
#  'data/results_prwp.jsonl']

# %%
df = pd.concat([pd.read_json(x, lines=True) for x in files]).reset_index(drop=True)
df
# Out:
#                                           snapshot_id   source    model  \
# 0   027_Jordan-Emergency-Food-Security-Project_fig...  refugee  gpt-5.5
# 1   054_Sudan-Basic-Education-Emergency-Support-Pr...  refugee  gpt-5.5
# 2   134_PAD7340ARABIC00n0220020140Arabic01_figure_...  refugee  gpt-5.5
# 3   004_BOSIB-87c444de-4797-4bf9-b654-4932a7fb0112...  refugee  gpt-5.5
# 4                       202_multi0page_figure_000.png  refugee  gpt-5.5
# 5                        200_multi-page_table_004.png  refugee  gpt-5.5
# 6                        200_multi-page_table_003.png  refugee  gpt-5.5
# 7   054_Sudan-Basic-Education-Emergency-Support-Pr...  refugee  gpt-5.5
# 8                        195_multi-page_table_012.png  refugee  gpt-5.5
# 9   120_PAD1205-ARABIC-PAD-PP152646-PUBLIC-Box3932...  refugee  gpt-5.5
# 10        white_paper_social_media_3_0_figure_003.png    unhcr  gpt-5.5
# 11  rapport_mensuel_monitoring_de_protection_de_la...    unhcr  gpt-5.5
# 12  refugee_and_migrant_children_in_europe_-_accom...    unhcr  gpt-5.5
# 13  rbsa_population_data_analysis_aug_2022_figure_...    unhcr  gpt-5.5
# 14  rapport_du_monitoring_de_protection_de_la_regi...    unhcr  gpt-5.5
# 15     08072015_northgovernorateprofile_table_000.png    unhcr  gpt-5.5
# 16  jun_2023_rbsa_population_data_analysis_table_0...    unhcr  gpt-5.5
# 17  note-dinformation---le-mouvement-des-rapatries...    unhcr  gpt-5.5
# 18  lebanoninter-agencythematicupdate-youthstudy-2...    unhcr  gpt-5.5
# 19  nov_2023_rbsa_population_data_analysis_table_0...    unhcr  gpt-5.5
# 20                   document_12916918_figure_002.png     prwp  gpt-5.5
# 21                   document_11777361_figure_010.png     prwp  gpt-5.5
# 22                   document_13840629_figure_008.png     prwp  gpt-5.5
# 23                    document_7581269_figure_000.png     prwp  gpt-5.5
# 24                    document_8772744_figure_012.png     prwp  gpt-5.5
# 25                      document_443630_table_025.png     prwp  gpt-5.5
# 26                      document_443630_table_005.png     prwp  gpt-5.5
# 27                      document_443630_table_022.png     prwp  gpt-5.5
# 28                    document_12736370_table_006.png     prwp  gpt-5.5
# 29                    document_10087951_table_005.png     prwp  gpt-5.5
#
#                                            raw_output  \
# 0   {"fields":[{"metadata_field":"figure_title","o...
# 1   {"fields":[{"metadata_field":"figure_title","o...
# 2   {"fields":[{"metadata_field":"figure_title","o...
# 3   {"fields":[{"metadata_field":"figure_title","o...
# 4   {"fields":[{"metadata_field":"geographic_scope...
# 5   {"fields":[{"metadata_field":"table_title","ob...
# 6   {"fields":[{"metadata_field":"table_title","ob...
# 7   {"fields":[{"metadata_field":"table_title","ob...
# 8   {"fields":[{"metadata_field":"table_title","ob...
# 9   {"fields":[{"metadata_field":"table_title","ob...
# 10  {"fields":[{"metadata_field":"figure_title","o...
# 11  {"fields":[{"metadata_field":"figure_title","o...
# 12  {"fields":[{"metadata_field":"visualization_ty...
# 13  {"fields":[{"metadata_field":"figure_title","o...
# 14  {"fields":[{"metadata_field":"visualization_ty...
# 15  {"fields":[{"metadata_field":"figure_title","o...
# 16  {"fields":[{"metadata_field":"table_title","ob...
# 17  {"fields":[{"metadata_field":"table_title","ob...
# 18  {"fields":[{"metadata_field":"figure_title","o...
# 19  {"fields":[{"metadata_field":"table_title","ob...
# 20  {"fields":[{"metadata_field":"figure_title","o...
# 21  {"fields":[{"metadata_field":"figure_title","o...
# 22  {"fields":[{"metadata_field":"figure_title","o...
# 23  {"fields":[{"metadata_field":"figure_title","o...
# 24  {"fields":[{"metadata_field":"figure_number","...
# 25  {"fields":[{"metadata_field":"table_title","ob...
# 26  {"fields":[{"metadata_field":"table_title","ob...
# 27  {"fields":[{"metadata_field":"table_title","ob...
# 28  {"fields":[{"metadata_field":"table_title","ob...
# 29  {"fields":[{"metadata_field":"table_title","ob...
#
#                                                 usage  \
# 0   {'input_tokens': 7168, 'input_tokens_details':...
# 1   {'input_tokens': 13799, 'input_tokens_details'...
# 2   {'input_tokens': 13286, 'input_tokens_details'...
# 3   {'input_tokens': 8299, 'input_tokens_details':...
# 4   {'input_tokens': 12161, 'input_tokens_details'...
# 5   {'input_tokens': 9304, 'input_tokens_details':...
# 6   {'input_tokens': 10634, 'input_tokens_details'...
# 7   {'input_tokens': 13554, 'input_tokens_details'...
# 8   {'input_tokens': 14962, 'input_tokens_details'...
# 9   {'input_tokens': 5548, 'input_tokens_details':...
# 10  {'input_tokens': 4298, 'input_tokens_details':...
# 11  {'input_tokens': 2119, 'input_tokens_details':...
# 12  {'input_tokens': 2532, 'input_tokens_details':...
# 13  {'input_tokens': 11472, 'input_tokens_details'...
# 14  {'input_tokens': 2395, 'input_tokens_details':...
# 15  {'input_tokens': 2407, 'input_tokens_details':...
# 16  {'input_tokens': 9089, 'input_tokens_details':...
# 17  {'input_tokens': 3227, 'input_tokens_details':...
# 18  {'input_tokens': 2205, 'input_tokens_details':...
# 19  {'input_tokens': 9852, 'input_tokens_details':...
# 20  {'input_tokens': 8200, 'input_tokens_details':...
# 21  {'input_tokens': 12364, 'input_tokens_details'...
# 22  {'input_tokens': 11887, 'input_tokens_details'...
# 23  {'input_tokens': 13000, 'input_tokens_details'...
# 24  {'input_tokens': 10670, 'input_tokens_details'...
# 25  {'input_tokens': 10332, 'input_tokens_details'...
# 26  {'input_tokens': 5661, 'input_tokens_details':...
# 27  {'input_tokens': 6750, 'input_tokens_details':...
# 28  {'input_tokens': 5862, 'input_tokens_details':...
# 29  {'input_tokens': 13581, 'input_tokens_details'...
#
#                                                  cost     status  \
# 0   {'input_tokens': 7168, 'output_tokens': 2431, ...  completed
# 1   {'input_tokens': 13799, 'output_tokens': 1576,...  completed
# 2   {'input_tokens': 13286, 'output_tokens': 1460,...  completed
# 3   {'input_tokens': 8299, 'output_tokens': 2116, ...  completed
# 4   {'input_tokens': 12161, 'output_tokens': 2134,...  completed
# 5   {'input_tokens': 9304, 'output_tokens': 1526, ...  completed
# 6   {'input_tokens': 10634, 'output_tokens': 1530,...  completed
# 7   {'input_tokens': 13554, 'output_tokens': 1939,...  completed
# 8   {'input_tokens': 14962, 'output_tokens': 1525,...  completed
# 9   {'input_tokens': 5548, 'output_tokens': 1514, ...  completed
# 10  {'input_tokens': 4298, 'output_tokens': 1479, ...  completed
# 11  {'input_tokens': 2119, 'output_tokens': 1288, ...  completed
# 12  {'input_tokens': 2532, 'output_tokens': 1972, ...  completed
# 13  {'input_tokens': 11472, 'output_tokens': 2163,...  completed
# 14  {'input_tokens': 2395, 'output_tokens': 1598, ...  completed
# 15  {'input_tokens': 2407, 'output_tokens': 1350, ...  completed
# 16  {'input_tokens': 9089, 'output_tokens': 1593, ...  completed
# 17  {'input_tokens': 3227, 'output_tokens': 1398, ...  completed
# 18  {'input_tokens': 2205, 'output_tokens': 1408, ...  completed
# 19  {'input_tokens': 9852, 'output_tokens': 1614, ...  completed
# 20  {'input_tokens': 8200, 'output_tokens': 1986, ...  completed
# 21  {'input_tokens': 12364, 'output_tokens': 1904,...  completed
# 22  {'input_tokens': 11887, 'output_tokens': 1468,...  completed
# 23  {'input_tokens': 13000, 'output_tokens': 1345,...  completed
# 24  {'input_tokens': 10670, 'output_tokens': 1379,...  completed
# 25  {'input_tokens': 10332, 'output_tokens': 1497,...  completed
# 26  {'input_tokens': 5661, 'output_tokens': 1421, ...  completed
# 27  {'input_tokens': 6750, 'output_tokens': 1534, ...  completed
# 28  {'input_tokens': 5862, 'output_tokens': 1472, ...  completed
# 29  {'input_tokens': 13581, 'output_tokens': 1537,...  completed
#
#     incomplete_details                                      parsed_output  \
# 0                  NaN  {'fields': [{'metadata_field': 'figure_title',...
# 1                  NaN  {'fields': [{'metadata_field': 'figure_title',...
# 2                  NaN  {'fields': [{'metadata_field': 'figure_title',...
# 3                  NaN  {'fields': [{'metadata_field': 'figure_title',...
# 4                  NaN  {'fields': [{'metadata_field': 'geographic_sco...
# 5                  NaN  {'fields': [{'metadata_field': 'table_title', ...
# 6                  NaN  {'fields': [{'metadata_field': 'table_title', ...
# 7                  NaN  {'fields': [{'metadata_field': 'table_title', ...
# 8                  NaN  {'fields': [{'metadata_field': 'table_title', ...
# 9                  NaN  {'fields': [{'metadata_field': 'table_title', ...
# 10                 NaN  {'fields': [{'metadata_field': 'figure_title',...
# 11                 NaN  {'fields': [{'metadata_field': 'figure_title',...
# 12                 NaN  {'fields': [{'metadata_field': 'visualization_...
# 13                 NaN  {'fields': [{'metadata_field': 'figure_title',...
# 14                 NaN  {'fields': [{'metadata_field': 'visualization_...
# 15                 NaN  {'fields': [{'metadata_field': 'figure_title',...
# 16                 NaN  {'fields': [{'metadata_field': 'table_title', ...
# 17                 NaN  {'fields': [{'metadata_field': 'table_title', ...
# 18                 NaN  {'fields': [{'metadata_field': 'figure_title',...
# 19                 NaN  {'fields': [{'metadata_field': 'table_title', ...
# 20                 NaN  {'fields': [{'metadata_field': 'figure_title',...
# 21                 NaN  {'fields': [{'metadata_field': 'figure_title',...
# 22                 NaN  {'fields': [{'metadata_field': 'figure_title',...
# 23                 NaN  {'fields': [{'metadata_field': 'figure_title',...
# 24                 NaN  {'fields': [{'metadata_field': 'figure_number'...
# 25                 NaN  {'fields': [{'metadata_field': 'table_title', ...
# 26                 NaN  {'fields': [{'metadata_field': 'table_title', ...
# 27                 NaN  {'fields': [{'metadata_field': 'table_title', ...
# 28                 NaN  {'fields': [{'metadata_field': 'table_title', ...
# 29                 NaN  {'fields': [{'metadata_field': 'table_title', ...
#
#     error
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN

# %%
# df = df[df["model"] == "gpt-5.4-mini"].copy()

# %% [markdown]
# # Cost

# %%
df = df.reset_index(drop=True).join(pd.json_normalize(df["cost"]))

total = df["total_cost_usd"].sum()
mean = df["total_cost_usd"].mean()
std = df["total_cost_usd"].std()

print(f"Total cost: ${total:.2f}")
print(f"Ave cost per snapshot: ${mean:.4f}")
print(f"Std dev: ${std:.4f}")
# Out:
# Total cost: $2.76
# Ave cost per snapshot: $0.0919
# Std dev: $0.0238

# %%
df.groupby(["source", "model"]).agg(
    count=("source", "count"),
    total_cost_usd=("total_cost_usd", "sum"),
    ave_cost_usd=("total_cost_usd", "mean"),
    std_cost_usd=("total_cost_usd", "std"),
)
# Out:
#                  count  total_cost_usd  ave_cost_usd  std_cost_usd
# source  model
# prwp    gpt-5.5     10        0.957825      0.095783      0.016384
# refugee gpt-5.5     10        1.076105      0.107611      0.016277
# unhcr   gpt-5.5     10        0.723870      0.072387      0.024175

# %% [markdown]
# # Output tokens

# %%
total = df["output_tokens"].sum()
mean = df["output_tokens"].mean()
std = df["output_tokens"].std()

print(f"Total output tokens: {total}")
print(f"Ave output token per snapshot: {mean}")
print(f"Std dev: {std:.2f}")
# Out:
# Total output tokens: 49157
# Ave output token per snapshot: 1638.5666666666666
# Std dev: 293.83

# %%
df.groupby(["source", "model"]).agg(
    count=("source", "count"),
    total_output_tokens=("output_tokens", "sum"),
    ave_output_tokens=("output_tokens", "mean"),
    std_output_tokens=("output_tokens", "std"),
)
# Out:
#                  count  total_output_tokens  ave_output_tokens  \
# source  model
# prwp    gpt-5.5     10                15543             1554.3
# refugee gpt-5.5     10                17751             1775.1
# unhcr   gpt-5.5     10                15863             1586.3
#
#                  std_output_tokens
# source  model
# prwp    gpt-5.5         215.812702
# refugee gpt-5.5         348.626974
# unhcr   gpt-5.5         280.055173

# %% [markdown]
# # Raw output

# %%
# df

# %%
# df.loc[0, "raw_output"]

# %% [markdown]
# # Parsed output

# %%
# df.loc[0, "parsed_output"]["fields"]
