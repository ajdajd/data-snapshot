# %% [markdown]
# # Data Snapshot Metadata Schema v1.1 validation
#
# Run the 12-snapshot calibration first. After the prompts and response model are frozen, change the three run-specific paths to process the complete 202-snapshot sample into fresh output files.

# %%
from data_snapshot.constants import ROOT
from data_snapshot.schema_validation import run_validation

# %%
# Calibration run
SNAPSHOTS_DIR = ROOT / "notebooks/schema_validation/data/subsample"
METADATA_DIR = ROOT / "notebooks/schema_validation/data/metadata"
SCHEMA_PATH = ROOT / "src/data_snapshot/metadata_extraction/schema/Data Snapshot Metadata Schema v1.1.md"
CONFIG_PATH = ROOT / "src/data_snapshot/schema_validation/config/default.json"
RESULTS_PATH = ROOT / "notebooks/schema_validation/outputs/calibration_results.jsonl"
ERRORS_PATH = ROOT / "notebooks/schema_validation/outputs/calibration_errors.jsonl"
SLEEP_SECONDS = 0.2

# %%
run_arguments = {
    "snapshots_dir": SNAPSHOTS_DIR,
    "metadata_dir": METADATA_DIR,
    "schema_path": SCHEMA_PATH,
    "results_path": RESULTS_PATH,
    "errors_path": ERRORS_PATH,
    "config_path": CONFIG_PATH,
    "sleep_seconds": SLEEP_SECONDS,
}
run_arguments
# Out:
# {'snapshots_dir': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation/data/subsample'),
#  'metadata_dir': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation/data/metadata'),
#  'schema_path': PosixPath('/home/ajd/data-snapshot-annotation/src/data_snapshot/metadata_extraction/schema/Data Snapshot Metadata Schema v1.1.md'),
#  'results_path': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation/outputs/calibration_results.jsonl'),
#  'errors_path': PosixPath('/home/ajd/data-snapshot-annotation/notebooks/schema_validation/outputs/calibration_errors.jsonl'),
#  'config_path': PosixPath('/home/ajd/data-snapshot-annotation/src/data_snapshot/schema_validation/config/default.json'),
#  'sleep_seconds': 0.2}

# %%
summary = run_validation(**run_arguments)
summary
# Out:
# Validating snapshots:   0%|          | 0/12 [00:00<?, ?snapshot/s]
# /home/ajd/miniconda3/envs/data-snapshot/lib/python3.10/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(PydanticSerializationUnexpectedValue: Expected `none` - serialized value may not be as expected [field_name='parsed', input_value=SchemaValidationResult(ob...candidate_new_fields=[]), input_type=SchemaValidationResult]
# PydanticSerializationUnexpectedValue: Expected `ResponseOutputRefusal` - serialized value may not be as expected [field_name='content', input_value=ParsedResponseOutputText[...andidate_new_fields=[])), input_type=ParsedResponseOutputText[~TextFormatT]])
#   PydanticSerializationUnexpectedValue(Expected `ParsedResponseFunctionToolCall` - serialized value may not be as expected [field_name='output', input_value=ParsedResponseOutputMessa...', phase='final_answer'), input_type=ParsedResponseOutputMessage[~TextFormatT]])
# ...
